# %% [markdown]
# # Example Notebook
#
# This is an example notebook.
#
# Modify / remove any of the below as suited for your needs

# %% [markdown]
# ## Setup

# %%
# package install 
# !pip3 install flake8
# !pip3 install m2r
# !pip3 install nbformat
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install pytest
# !pip3 install pytest-cookies
# !pip3 install pytest-cov
# !pip3 install sphinx
# !pip3 install spacy
# !pip3 install nltk
# !pip3 install wordcloud


# Standard python packages
import os
import sys
import string
# # for natural language processing: named entity recognition
# import spacy
# from spacy.displacy.render import EntityRenderer
# from IPython.core.display import display, HTML

# Other package imports
import numpy as np
import pandas as pd
import nltk


# if uising a Jupyter notebook, include:

# Visualization packages
from wordcloud import WordCloud
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %% [markdown]
# Setup some global settings and configuration

# %%
project_root = os.path.abspath(os.path.join(os.pardir, os.pardir))
data_folder = os.path.join(project_root, 'data')
data_folder_raw = os.path.join(data_folder, 'raw')
src_folder = os.path.join(project_root, 'src')
print(project_root)
print(data_folder)
print(data_folder_raw)
print(src_folder)
# Out:
# /notebooks
# /notebooks/data
# /notebooks/data/raw
# /notebooks/src

# %% [markdown]
# This notebook uses the shared package however first we need to ensure it is available (otherwise you get an error about the module not being found). You can either run setup.py as discussed in the readme to install the package or modify the path to include the src folder.

# %%
# Explicitly set path so don't need to run setup.py - if we have multiple copies of 
# the code we would otherwise need to setup a seperate environment for each to
# ensure the code pointers are correct.
sys.path.insert(0, "../src")

from neraccidente import examplemodule

# %% [markdown]
# ## Some Processing

# %% [markdown]
# ## Appendix 1 - Environment Configuration

# %%
print (os.getcwd())
print (sys.version)
print (sys.executable)
print (sys.path)
# Out:
# /notebooks/ner-accidente/notebooks
# 3.8.2 (default, Jul 16 2020, 14:00:26)
# [GCC 9.3.0]
# /usr/bin/python3
# ['../src', '/notebooks/ner-accidente/notebooks', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython']

# %% [markdown]
# ## Appendix 2 - Automated Tests

# %%
# Run tests within notebook
f_path = os.getcwd()
os.chdir(os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir)))

# Run pytest from the repository root
# !pytest

os.chdir(f_path)
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.2, pytest-5.4.3, py-1.9.0, pluggy-0.13.1
# rootdir: /notebooks
# plugins: cov-2.10.1, cookies-0.5.1
# collected 5 items / 3 errors / 2 selected
#
# ==================================== ERRORS ====================================
# ____________ ERROR collecting ner-accidente/tests/test_notebook.py _____________
# import file mismatch:
# imported module 'test_notebook' has this __file__ attribute:
#   /notebooks/ml_basic/tests/test_notebook.py
# which is not the same as the test file we want to collect:
#   /notebooks/ner-accidente/tests/test_notebook.py
# HINT: remove __pycache__ / .pyc files and/or use a unique basename for your test file modules
# _ ERROR collecting ner-accidente/tests/neraccidente/examplemodule/test_add_value_to_numpy.py _
# import file mismatch:
# imported module 'test_add_value_to_numpy' has this __file__ attribute:
#   /notebooks/ml_basic/tests/ml_basic/examplemodule/test_add_value_to_numpy.py
# which is not the same as the test file we want to collect:
#   /notebooks/ner-accidente/tests/neraccidente/examplemodule/test_add_value_to_numpy.py
# HINT: remove __pycache__ / .pyc files and/or use a unique basename for your test file modules
# _ ERROR collecting ner-accidente/tests/neraccidente/examplemodule/test_hello_world.py _
# import file mismatch:
# imported module 'test_hello_world' has this __file__ attribute:
#   /notebooks/ml_basic/tests/ml_basic/examplemodule/test_hello_world.py
# which is not the same as the test file we want to collect:
#   /notebooks/ner-accidente/tests/neraccidente/examplemodule/test_hello_world.py
# HINT: remove __pycache__ / .pyc files and/or use a unique basename for your test file modules
# =========================== short test summary info ============================
# ERROR ner-accidente/tests/test_notebook.py
# ERROR ner-accidente/tests/neraccidente/examplemodule/test_add_value_to_numpy.py
# ERROR ner-accidente/tests/neraccidente/examplemodule/test_hello_world.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 3 errors during collection !!!!!!!!!!!!!!!!!!!!
# ============================== 3 errors in 0.25s ===============================

# %%
# import our dataSet for analysis
path = os.path.join('../data', 'raw', 'ner - locatia accidente.csv')
# print(path)

df = pd.read_csv(path)
# print(f"Loaded {accident_data.shape[0]} samples.")

# select the only the rows that has marked words y=1
df = df.loc[df['y'] == 1]


print(df)
# Out:
#       id  y                                               text  com
# 0      0  1  un sofer a tamponat o femeie pe trecerea pieto...  NaN
# 1      1  1  aseara jurul orei 2330 politia capitalei a fos...  NaN
# 2      6  1  accidentul s a intamplat aceasta dimineata pe ...  NaN
# 3      7  1  un pieton a fost spulberat mortal aseara un ta...  NaN
# 4     10  1  accidentul a avut loc sectorul botanica pe ||s...  NaN
# ..   ... ..                                                ...  ...
# 150  370  1  intersectia strazilor ||vadul|| ||lui|| ||voda...  NaN
# 151  371  1  un accident lant a avut loc aceasta dimineata ...  NaN
# 152  373  1  potrivt politei accidentul a avut loc acum o o...  NaN
# 153  375  1  accidentul s a produs astazi intersectia ||bul...  NaN
# 154  376  1  un barbat moarte dupa ce inima acestuia s a op...  NaN
#
# [153 rows x 4 columns]

# %%
def generate_cloud(data_frame):
    all_words = ''
    for arg in data_frame:
        tokens = arg.split()  
        all_words += " ".join(tokens)+" "
#         print (all_words)
    wordcloud = WordCloud(width = 700, height = 700, background_color ='white', min_font_size = 10).generate(all_words) 
    # plot the WordCloud image                        
    plt.figure(figsize = (5, 5), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# %%
# TIME TO DETECT ENTITIES AND CLEAN THE TEXT
import spacy
from spacy import displacy
# install romanian models
# !python3 -m spacy download ro_core_news_lg

#Plot and image tools
from PIL import Image
from matplotlib import pyplot as plt
from matplotlib import gridspec
import matplotlib.ticker as mticker
import seaborn as sns
sns.set_style("dark")

nlp = spacy.load("ro_core_news_lg")
all_stopwords = nlp.Defaults.stop_words

# lower the text so that it all is in lowercase
df['text'] = df['text'].str.lower()
# remove all stop words that appear in the romanian text corpus


# Display the relationship between the words in phrases
# doc = nlp(df['text'][1])
# displacy.render(doc, style="dep", jupyter=True, options={'distance':140})




df['text_no_sw'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (all_stopwords)]))

# %%
# df["text"] = df["text"].str.replace('\xa0',' ')
# df["text"] = df["text"].str.replace('|',' ')

# df['text_no_sw'] = df['text_no_sw'].str.replace('\xa0',' ')
# df['text_no_sw'] = df['text_no_sw'].str.replace('|',' ')
# df['text_no_sw'] = df['text_no_sw'].str.replace('   ',' ')
# df['text_no_sw'] = df['text_no_sw'].str.replace('  ',' ')
# df['text_no_sw'] = df['text_no_sw'].str.replace('  ',' ')

# all_text_list = df['text_no_sw'].tolist()
# # all_text_list

# free_list = []
# for phrase in all_text_list:
# #     print(phrase)
#     free_list.append(phrase)
#     split_data = phrase.split(",")
# #     print(split_data)

# print(split_data)

# %%
def plot_word_freq(text_to_plot, title='Placeholder title'):
    fd2 = nltk.FreqDist(word for word in text_to_plot)      
    x=[fd2.most_common(55)[i][0] for i in range(55)]
    y=[fd2.most_common(55)[i][1] for i in range(55)]

    #palette=sns.color_palette("PuBuGn_d",100)
    palette= sns.light_palette("crimson",100,reverse=True)
    plt.figure(figsize=(65,25))
    ax= sns.barplot(x, y, alpha=0.8,palette=palette)
    plt.title(title, fontsize=110)
    plt.ylabel('Occurrences', fontsize=190)
    plt.xlabel(' Word ', fontsize=110)
    #adding the text labels
    rects = ax.patches
    labels = y
    sns.set(font_scale=3)
    for rect, label in zip(rects, labels):
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, height + 1, label, ha='center', va='bottom')
        plt.xticks(rotation=90, fontsize=50)
    #plt.savefig('Toxic_Word_count1.png')    
    plt.show()


def generate_cloud(data_frame):
    all_words = ''
    for arg in data_frame:
        tokens = arg.split()  
        all_words += " ".join(tokens)+" "
#         print (all_words)
    wordcloud = WordCloud(width = 1000, height = 1000, background_color ='white', min_font_size = 10).generate(all_words) 
    # plot the WordCloud image                        
    plt.figure(figsize = (5, 5), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()
    

## Find all the words that exist in both lists
def get_words_that_appear_in_both(text_inpul_1,text_input_2):
    same_words = set(text_inpul_1).intersection(text_input_2)
    same_words = list(same_words)
    print(same_words)
    return same_words


def detect_entities_in_dataframe(dataframe):
    for sentence in dataframe:
        ## print named entities in phrases
        sentence_nlp = nlp(sentence)
        print([(word, word.ent_type_) for word in sentence_nlp if word.ent_type_])
        # # visualize named entities
        displacy.render(sentence_nlp, style='ent', jupyter=True)

# %% [markdown]
# # Parse and analyse the whole text corpus

# %%
# df['text'] = df['text'].str.replace('\xa0',' ')
# df['text'] = df['text'].str.replace('|',' ')
# df['text'] = df['text'].str.replace('   ',' ')
# df['text'] = df['text'].str.replace('  ',' ')
# df['text'] = df['text'].str.replace('  ',' ')

print(df['text'].head)
all_corpus_text = []
for phrases in df["text"]:
    phrases = phrases.split(" ")
    for words in phrases:
        all_corpus_text.append(words)

generate_cloud(df["text"])          
plot_word_freq(all_corpus_text, title='All words frequency')
# Out:
# <bound method NDFrame.head of 0      un sofer a tamponat o femeie pe trecerea pieto...
# 1      aseara jurul orei 2330 politia capitalei a fos...
# 2      accidentul s a intamplat aceasta dimineata pe ...
# 3      un pieton a fost spulberat mortal aseara un ta...
# 4      accidentul a avut loc sectorul botanica pe ||s...
#                              ...
# 150    intersectia strazilor ||vadul|| ||lui|| ||voda...
# 151    un accident lant a avut loc aceasta dimineata ...
# 152    potrivt politei accidentul a avut loc acum o o...
# 153    accidentul s a produs astazi intersectia ||bul...
# 154    un barbat moarte dupa ce inima acestuia s a op...
# Name: text, Length: 153, dtype: object>

# %% [markdown]
# # Parse and analyse the marked words from the text-corpus

# %%
all_marked_text = []
all_unmarked_text = []
for phrases in df['text_no_sw']:
#     print('1' + phrases)
    phrases = phrases.split(" ")
    for words in phrases:
#         print(phrase)
        i_processed = words.replace("|","")
        if "|" in words:
            all_marked_text.append(i_processed)
        else:
            all_unmarked_text.append(words)

# Visualize text that has not been annotated    
# print(all_marked_text)
print(len(all_marked_text))
generate_cloud(all_marked_text)
plot_word_freq(all_marked_text, title='Marked text frequency')
# Out:
# 1sofer tamponat femeie trecerea pietoni intersectia ||bd decebal|| ||strada|| ||trandafirilor|| potrivit politiei persoana traumata luata ambulanta transportata urgenta spital
# 1aseara jurul orei 2330 politia capitalei alertata inversarea automobil ||traseul|| duce ||spre|| ||localitatea|| ||cheltuitori|| soldat decesul persoane altele traumatizate grav locului intervenit grupa ope
# 1accidentul intamplat dimineata ||soseaua|| ||muncesti|| capitala
# 1pieton spulberat mortal aseara taxi accidentul produs ||soseaua|| ||muncesti|| capitala jurul orei 21:00
# 1accidentul loc sectorul botanica ||strada|| ||trandafirilor|| jurul orei 20:00
# 1doua masini ciocnit aseara intersectia ||bulevardel||or ||dacia|| ||traian|| capitala urma impactului taxi rasturnat celalalt automobil avariat
# 1accident rutier intersectia strazilor ||columna|| – ||maria|| ||cebotari|| automobil model „bmw” volanul afla sofer varsta 22 ani lovit kamaz urma acestuia pasager suf
# 1update/foto accident intersectia ||columna|| ||maria|| ||cebotari||: automobil lovit kamaz
# 1update/foto accident intersectia ||columna|| ||maria|| ||cebotari||: automobil tamponat intrun kamaz
# 1accident evitat minune intamplat balti intersectia strazilor ||ivano|| ||franco|| ||bulgara||
# 1accidentul loc ||strada|| ||mihai|| ||viteazul|| capitala
# 1accident grav capitala intersectia strazilor ||sfatul|| tarii stefan doua autovehicole ciocnit violent imaginea distribuita retea socializare martor oc||sfatul|| ||tarii|| ||stefan||
# 1accident ||strada|| ||calea|| ||iesilor|| capitala ||apropiere|| intersectia strada ||mesager|| automobil model bmw ajuns stalp soferul autoturismului transportat spital
# 1accidentul loc aseara ||strada|| ||calea|| ||iesilor|| sectorul buiucani capitalei trecatorii primii scos victimele automobilele avariate "soferul rasufla
# 1accident capitala! doua automobile ciocnit intersectia strazii ||alba|| ||iulia|| ||sucevita|| informeaza agora potrivi martorilor oculari locului afla politia inregistrati raniti
# 1accident grav intersectia strazilor ||alba|| ||iulia|| ||paris|| capitala masina model volvo xc90 afla stare deplorabila lovit violent masina
# 1accident rutier inregistrat dimineata strada ||vissarion|| belinski intersectie strada ion pelivan capit||ion|| ||belinski|| intersectie ||strada|| ion ||pelivan|| capitala
# 1masina politiei intrat seara jurul orei 23:00 gard bloc locuit ||strada|| ||alba|| ||iulia|| ||75/22|| sectorul buiucani capitalei
# 1potrivit politiei intamplat jurul orei 10:00 ||strada|| ||sarmisegetuza|| sectorul botanica capitalei mercedes grav avariat ciocnit violent kia
# 1accident dimineata capitala masini tamponat ||bulevardul|| ||stefan|| ||cel|| ||mare|| ||strada|| ||petru|| ||movila|| automobil dacia franat brusc semafor doua masini nerespectand distanta tamponat
# 1sofer decedat locului masina rupta doua propriu accident loc dimineata ||traseul|| ||budesti|| ||cruzesti|| municipiul chisinau
# 1potrivt politei accidentul loc ora ||pod||ul intersectia strazilor ||muncesti|| ||gradina|| ||botanica|| soferul mercedes pierdut controlul volanului derapat rasturnat
# 1accidentul produs intersectia ||bulevardul||ui ||stefan|| ||cel|| ||mare|| ||strada|| ||mihai|| ||eminescu|| automobil ciocnit troleibuzin urma impactului automobilul grav avariat banda
# 1barbat moarte inima acestuia oprit fiind lovit masina travesa strada incidentul loc aseara intersectia strazilor ||vasile|| ||alecsandri|| ||mitropolit|| ||varlaam|| centrul capitalei
# 524

# %% [markdown]
# # Parse and analyse the unmarked words from the text-corpus

# %%
# Visualize text that has not been annotated
# print(all_unmarked_text)
print(len(all_unmarked_text))
generate_cloud(all_unmarked_text)
plot_word_freq(all_unmarked_text, title='Unmarked text frequency')
# Out:
# 2093

# %% [markdown]
# # Parse and analyse words from both marked and unmarked text-corspus

# %%
from collections import Counter

# count the frequency of elements of list1 in list2
def cntFrequency(lst1,lst2):
    dct=dict(Counter(lst2))
    sub_dct={k:dct.get(k,0) for k in lst1}
    return sub_dct

same_words = cntFrequency(all_marked_text,all_unmarked_text)
# print (same_words)


generate_cloud(same_words)
plot_word_freq(same_words, title='Words that appear in both text-bases')
# Out:
# {'bd': 1, 'decebal': 0, 'strada': 18, 'trandafirilor': 1, 'traseul': 4, 'spre': 0, 'localitatea': 4, 'cheltuitori': 0, 'soseaua': 4, 'muncesti': 0, 'bulevardelor': 0, 'dacia': 2, 'traian': 0, 'columna': 0, 'maria': 0, 'cebotari': 0, 'cebotari:': 0, 'ivano': 0, 'franco': 0, 'bulgara': 0, 'mihai': 0, 'viteazul': 0, 'sfatul': 0, 'ocsfatul': 0, 'tarii': 1, 'stefan': 3, 'calea': 2, 'iesilor': 1, 'apropiere': 5, 'mesager': 0, 'alba': 0, 'iulia': 0, 'sucevita': 0, 'paris': 0, 'vissarion': 0, 'capition': 0, 'belinski': 1, 'pelivan': 1, '75/22': 0, 'sarmisegetuza': 0, 'bulevardul': 0, 'cel': 0, 'mare': 0, 'petru': 0, 'movila': 0, 'budesti': 0, 'cruzesti': 0, 'chisinau': 13, 'hancesti': 0, 'intersectie': 11, 'satul': 10, 'danceni': 0, 'vasile': 0, 'alecsandri': 0, 'svetlai': 0, 'comrat': 0, 'leuseni': 0, 'bucuresti': 0, 'rublenita': 0, 'noua': 0, 'alexei': 0, 'sciusev': 0, 'rezina': 0, 'chipirceni': 0, 'orasul': 2, 'bender': 1, 'langa': 2, 'gvozdova': 0, 'floresti': 0, 'ungheni': 2, 'sculeni': 0, 'cimislia': 0, 'buiucani': 5, 'dintre': 0, 'satele': 0, 'isnovat': 0, 'stetcani': 0, 'criuleni': 1, 'dimitrie': 0, 'cantemir': 0, 'capitala': 24, 'panin': 0, 'statia': 0, 'azs': 0, '51': 0, 'viaduct': 0, 'tohatin': 0, 'pererita': 0, 'briceni': 0, 'orei': 25, 'intrarea': 1, 'peresecina': 2, 'inspectoratului': 1, 'orhei': 4, 'podgorenilor': 0, 'hlinaia': 0, 'auto': 2, 'garii': 0, 'sensul': 0, 'giratoriu': 2, 'strpetricani': 0, 'supraten': 0, 'calarasi': 0, 'kiev': 0, 'puskin': 0, 'doina': 0, 'soatului': 0, 'soroca': 2, 'balcani': 0, 'viteazu': 0, 'serghei': 1, 'lazo': 0, 'testimitanu': 0, 'pirlita': 0, 'centurii': 0, 'ocolire': 0, 'zagarancea': 0, 'satului': 0, 'sfarsitul': 0, 'straseni': 2, 'marginea': 2, 'orasului': 6, 'voda': 2, 'dragan': 0, 'ciocana': 2, 'baimaclia': 0, 'causeni': 0, 'vadul': 0, 'lui': 0, 'banulescu': 0, 'bodoni': 0, 'august': 0, 'mai': 0, 'unirii': 2, 'independentei': 0, 'tudor': 0, 'vladimirescu': 0, 'balauresti': 0, 'nisporeni': 0, 'tintareni': 0, 'telenesti': 0, 'intre': 0, 'localitatile': 1, 'step': 0, 'soci': 0, 'chiperceni': 0, 'raionul': 23, 'dimo': 0, 'durlesti': 0, 'alecu': 1, 'russo': 1, 'sadoveanu': 0, 'soseau': 0, 'deleanu': 0, 'balabanul': 0, 'taraclia': 0, 'r16': 0, 'frumusica': 0, 'scalugar': 0, 'cornesti': 0, 'verejeni': 0, 'ion': 3, 'dumeniuc': 0, 'mircea': 0, 'batran': 1, 'periferia': 0, 'corjeuti': 0, 'braviceni': 0, 'volovita': 0, 'gheorghe': 0, 'asachi': 0, 'valecsandri': 0, 'besalma': 0, 'uta': 0, 'gagauzia': 0, 'masinistrada': 0, 'ciufleatriplu': 0, 'apropierea': 5, 'mihail': 0, 'kogilniceanu': 0, 'grigorievca': 0, 'baccealia': 0, 'drumul': 2, 'viilor': 0, 'george': 0, 'meniuc': 0, 'balti': 4, '„doi': 0, 'haiduci”': 0, 'iurceni': 0, 'cristesti': 0, 'ialoveni': 0, 'razeni': 0, 'eminescu': 0, 'alexandru': 0, 'bun': 0, 'ismail': 0, 'basarabiei': 1, 'strismail': 0, 'strcalea': 0, 'podului': 3, 'costiujeni': 0, 'intersectia': 36, 'strazilor': 23, 'ghibu': 0, 'romanvca': 0, 'sangerei': 2, 'creanga': 0, 'sfant': 0, 'miorita': 0, 'ganea': 0, 'lomonosov': 0, 'vlaicu': 0, 'parcalab': 0, 'kogalniceanu': 0, 'mateevici': 0, 'parcalabpotrivit': 0, 'pircalab': 0, 'bulervadul': 0, 'bulevardului': 0, 'armeneasca': 0, 'lupa': 0, 'recea': 0, 'eugen': 0, 'coca': 0, 'chryrada': 0, 'visarion': 1, 'belinschi': 1, 'studentilor': 0, 'orheiului': 0, 'ceucari': 0, 'podul': 0, 'mesterul': 0, 'manole': 0, 'gradina': 0, 'botanica': 5, 'mitropolit': 1, 'varlaam': 0}

# %%
# TIME TO DETECT ENTITIES AND CLEAN THE TEXT
import spacy
from spacy import displacy

# install romanian models
# !python3 -m spacy download ro_core_news_lg

nlp = spacy.load("ro_core_news_lg")
all_stopwords = nlp.Defaults.stop_words


# lower the text so that it all is in lowercase
df['text'] = df['text'].str.lower()
# remove all stop words that appear in the romanian text corpus
df['text_no_sw'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (all_stopwords)]))

# %%
df['text_no_sw_no_bars'] = df['text_no_sw'].str.replace('|','')

sentence = df['text_no_sw_no_bars'][12]

sentence
# Out:
# 'accident strada calea iesilor capitala apropiere intersectia strada mesager automobil model bmw ajuns stalp soferul autoturismului transportat spital'

# %% [markdown]
# ## Iterate over all rows in "df['text_no_sw_no_bars']" and highlight the entities

# %%
# # TIME TO DETECT ENTITIES 
detect_entities(df['text_no_sw_no_bars'])
# Out:
# [(bd, 'LOC'), (decebal, 'LOC'), (strada, 'LOC'), (trandafirilor, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">sofer tamponat femeie trecerea pietoni intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bd decebal strada trandafirilor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  potrivit politiei persoana traumata luata ambulanta transportata urgenta spital</div></span>
# [(aseara, 'DATETIME'), (jurul, 'DATETIME'), (orei, 'DATETIME'), (2330, 'NUMERIC_VALUE'), (alertata, 'ORGANIZATION'), (automobil, 'PRODUCT'), (cheltuitori, 'PERSON'), (persoane, 'PERSON')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aseara jurul orei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2330
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NUMERIC_VALUE</span>
# </mark>
#  politia capitalei
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alertata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANIZATION</span>
# </mark>
#  inversarea
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  traseul duce spre localitatea
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cheltuitori
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  soldat decesul
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     persoane
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  altele traumatizate grav locului intervenit grupa ope</div></span>
# [(soseaua, 'FACILITY'), (muncesti, 'FACILITY'), (capitala, 'FACILITY')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul intamplat dimineata
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soseaua muncesti capitala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FACILITY</span>
# </mark>
# </div></span>
# [(pieton, 'PERSON'), (aseara, 'NUMERIC_VALUE'), (taxi, 'PRODUCT'), (soseaua, 'FACILITY'), (muncesti, 'FACILITY'), (capitala, 'FACILITY')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pieton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  spulberat mortal
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aseara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NUMERIC_VALUE</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     taxi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  accidentul produs
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soseaua muncesti capitala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FACILITY</span>
# </mark>
#  jurul orei 21:00</div></span>
# [(sectorul, 'LOC'), (botanica, 'LOC'), (strada, 'LOC'), (trandafirilor, 'LOC'), (jurul, 'LOC'), (orei, 'LOC'), (20:00, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul loc
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sectorul botanica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada trandafirilor jurul orei 20:00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(masini, 'PRODUCT'), (bulevardelor, 'LOC'), (dacia, 'LOC'), (traian, 'LOC'), (capitala, 'LOC'), (urma, 'LOC'), (impactului, 'LOC'), (taxi, 'LOC'), (rasturnat, 'LOC'), (celalalt, 'LOC'), (automobil, 'LOC'), (avariat, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">doua
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     masini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ciocnit aseara intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bulevardelor dacia traian capitala urma impactului taxi rasturnat celalalt automobil avariat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(strazilor, 'LOC'), (columna, 'LOC'), (maria, 'PERSON'), (cebotari, 'PERSON'), (automobil, 'PERSON'), (model, 'PERSON'), („, 'PERSON'), (bmw, 'PERSON'), (”, 'PERSON'), (volanul, 'WORK_OF_ART'), (afla, 'WORK_OF_ART'), (sofer, 'WORK_OF_ART'), (22, 'DATETIME'), (ani, 'DATETIME'), (kamaz, 'GPE'), (pasager, 'PERSON')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident rutier intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor columna
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  –
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maria cebotari automobil model „bmw”
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     volanul afla sofer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  varsta
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22 ani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  lovit
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kamaz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  urma acestuia
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pasager
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  suf</div></span>
# [(columna, 'LOC'), (maria, 'LOC'), (cebotari, 'LOC'), (automobil, 'PRODUCT'), (kamaz, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">update/foto accident intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     columna maria cebotari
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# :
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  lovit
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kamaz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>
# [(columna, 'LOC'), (maria, 'LOC'), (cebotari, 'LOC'), (automobil, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">update/foto accident intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     columna maria cebotari
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# :
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  tamponat intrun kamaz</div></span>
# [(balti, 'LOC'), (intersectia, 'LOC'), (strazilor, 'LOC'), (ivano, 'LOC'), (franco, 'LOC'), (bulgara, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident evitat minune intamplat
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     balti intersectia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor ivano franco bulgara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(strada, 'LOC'), (mihai, 'LOC'), (viteazul, 'LOC'), (capitala, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul loc
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada mihai viteazul capitala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(strazilor, 'LOC'), (autovehicole, 'PRODUCT'), (martor, 'PERSON')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident grav capitala intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  sfatul tarii stefan doua
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     autovehicole
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ciocnit violent imaginea distribuita retea socializare
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     martor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ocsfatul tarii stefan</div></span>
# [(strada, 'LOC'), (calea, 'LOC'), (iesilor, 'LOC'), (capitala, 'LOC'), (strada, 'LOC'), (automobil, 'PRODUCT'), (model, 'PRODUCT'), (bmw, 'PRODUCT'), (soferul, 'PERSON'), (autoturismului, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada calea iesilor capitala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  apropiere intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  mesager
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil model bmw
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ajuns stalp
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soferul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     autoturismului
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  transportat spital</div></span>
# [(aseara, 'DATETIME'), (strada, 'LOC'), (calea, 'LOC'), (iesilor, 'LOC'), (sectorul, 'LOC'), (buiucani, 'LOC'), (capitalei, 'LOC'), (victimele, 'PERSON'), (automobilele, 'PRODUCT'), (soferul, 'PERSON'), (rasufla, 'PERSON')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul loc
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aseara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada calea iesilor sectorul buiucani capitalei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  trecatorii primii scos
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     victimele
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobilele
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  avariate &quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soferul rasufla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>
# [(doua, 'ORDINAL'), (automobile, 'PRODUCT'), (strazii, 'LOC'), (alba, 'LOC'), (iulia, 'LOC'), (sucevita, 'LOC'), (informeaza, 'LOC'), (agora, 'FACILITY'), (potrivi, 'FACILITY'), (martorilor, 'PERSON'), (raniti, 'GPE')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident capitala!
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     doua
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ciocnit intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazii alba iulia sucevita informeaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     agora potrivi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FACILITY</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     martorilor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  oculari locului afla politia inregistrati
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     raniti
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>
# [(strazilor, 'LOC'), (alba, 'LOC'), (iulia, 'LOC'), (paris, 'LOC'), (capitala, 'LOC'), (masina, 'LOC'), (model, 'LOC'), (volvo, 'LOC'), (xc90, 'LOC'), (masina, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident grav intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor alba iulia paris capitala masina model volvo xc90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  afla stare deplorabila lovit violent
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     masina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>
# [(strada, 'LOC'), (vissarion, 'LOC'), (belinski, 'LOC'), (intersectie, 'LOC'), (strada, 'LOC'), (ion, 'LOC'), (pelivan, 'LOC'), (capition, 'LOC'), (belinski, 'LOC'), (intersectie, 'LOC'), (strada, 'LOC'), (ion, 'LOC'), (pelivan, 'LOC'), (capitala, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident rutier inregistrat dimineata
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada vissarion belinski intersectie strada ion pelivan capition belinski intersectie strada ion pelivan capitala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(masina, 'PRODUCT'), (politiei, 'PRODUCT'), (seara, 'DATETIME'), (jurul, 'DATETIME'), (orei, 'DATETIME'), (23:00, 'DATETIME'), (strada, 'LOC'), (alba, 'LOC'), (iulia, 'LOC'), (75/22, 'LOC'), (sectorul, 'LOC'), (buiucani, 'LOC'), (capitalei, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     masina politiei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  intrat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seara jurul orei 23:00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  gard bloc locuit
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada alba iulia 75/22 sectorul buiucani capitalei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(strada, 'LOC'), (sarmisegetuza, 'LOC'), (sectorul, 'LOC'), (botanica, 'LOC'), (mercedes, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">potrivit politiei intamplat jurul orei 10:00
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada sarmisegetuza sectorul botanica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  capitalei
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mercedes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  grav avariat ciocnit violent kia</div></span>
# [(masini, 'PRODUCT'), (bulevardul, 'FACILITY'), (stefan, 'FACILITY'), (strada, 'LOC'), (petru, 'LOC'), (movila, 'LOC'), (automobil, 'LOC'), (dacia, 'LOC'), (franat, 'LOC'), (brusc, 'LOC'), (semafor, 'LOC'), (doua, 'LOC'), (masini, 'LOC'), (nerespectand, 'LOC'), (distanta, 'LOC'), (tamponat, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident dimineata capitala
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     masini
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  tamponat
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bulevardul stefan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FACILITY</span>
# </mark>
#  cel mare
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada petru movila automobil dacia franat brusc semafor doua masini nerespectand distanta tamponat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(masina, 'PRODUCT'), (doua, 'NUMERIC_VALUE'), (dimineata, 'DATETIME'), (traseul, 'LOC'), (budesti, 'LOC'), (cruzesti, 'LOC'), (municipiul, 'LOC'), (chisinau, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">sofer decedat locului
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     masina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  rupta
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     doua
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NUMERIC_VALUE</span>
# </mark>
#  propriu accident loc
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dimineata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     traseul budesti cruzesti municipiul chisinau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(57, 'DATETIME'), (ani, 'DATETIME'), (duminica, 'DATETIME'), (seara, 'DATETIME'), (22, 'DATETIME'), (octombrie, 'DATETIME'), (chisinau, 'ORGANIZATION'), (hancesti, 'ORGANIZATION'), (intersectie, 'ORGANIZATION'), (danceni, 'GPE'), (soferul, 'GPE')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">barbat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     57 ani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  accidentat mortal
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     duminica seara 22 octombrie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  traseul
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chisinau hancesti intersectie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANIZATION</span>
# </mark>
#  satul
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     danceni soferul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  parasit locul accidentului scurt retinut mentioneaza ipn</div></span>
# [(sambata, 'DATETIME'), (28, 'DATETIME'), (octombrie, 'DATETIME'), (jurul, 'DATETIME'), (orei, 'DATETIME'), (19:00, 'DATETIME'), (strada, 'LOC'), (vasile, 'LOC'), (alecsandri, 'LOC'), (cahul, 'LOC'), (soferul, 'LOC'), (autoturism, 'PRODUCT'), (model, 'PRODUCT'), („, 'PRODUCT'), (ford, 'PRODUCT'), (”, 'PRODUCT'), (55, 'DATETIME'), (ani, 'DATETIME'), (soferul, 'PERSON')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sambata 28 octombrie jurul orei 19:00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada vasile alecsandri cahul soferul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     autoturism model „ford”
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  tamponat barbat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     55 ani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soferul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  vinovat parasit locul accidentului scu</div></span>
# [(ion, 'PERSON'), (focsa, 'PERSON'), (seful, 'PERSON'), (28, 'DATETIME'), (octombrie, 'DATETIME'), (svetlai, 'GPE'), (comrat, 'GPE')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ion focsa seful
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  directiei sud politiei frontiera implicat data
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28 octombrie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  accident rutier localitatea
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     svetlai comrat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>
# [(doua, 'NUMERIC_VALUE'), (sambata, 'DATETIME'), (30, 'DATETIME'), (septembrie, 'DATETIME'), (chisinau, 'ORGANIZATION'), (leuseni, 'ORGANIZATION')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">grav avariate implicate accident rutier coliziunea
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     doua
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NUMERIC_VALUE</span>
# </mark>
#  unitati transport loc
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sambata 30 septembrie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  traseul
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chisinau leuseni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANIZATION</span>
# </mark>
# </div></span>
# [(strazilor, 'LOC'), (bucuresti, 'LOC'), (automobile, 'PRODUCT'), (tamponat, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident lant intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor bucuresti
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  sfatul tarii
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobile tamponat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  violent dimineata</div></span>
# [(martorilor, 'PERSON'), (soferul, 'PERSON'), (automobilului, 'PRODUCT'), (automobilul, 'PRODUCT'), (mercedes, 'PRODUCT'), (benz, 'PRODUCT'), (automobil, 'PRODUCT'), (ford, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">potrivit
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     martorilor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  vina
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soferul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobilului
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  marca jaguar circuland strada sfatul tarii asigurat lovit
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobilul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  marca
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mercedes benz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  ulterior lovit
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil ford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>
# [(ccident, 'ORGANIZATION'), (soroca, 'ORGANIZATION'), (implicarea, 'ORGANIZATION'), (microbuz, 'ORGANIZATION'), (ruta, 'ORGANIZATION'), (biciclist, 'ORGANIZATION')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ccident soroca implicarea microbuz ruta biciclist
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANIZATION</span>
# </mark>
#  decedat maxi taxi tragedia loc jurul orei 20:30 apropiere satul rublenita noua</div></span>
# [(alexei, 'LOC'), (sciusev, 'LOC'), (automobile, 'PRODUCT'), (proiectat, 'PRODUCT'), (pilon, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul loc intersectia strazilor sfatul tarii
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alexei sciusev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  urma coleziunii
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobile proiectat pilon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>
# [(sambata, 'DATETIME'), (seara, 'DATETIME'), (23, 'DATETIME'), (septembrie, 'DATETIME'), (jurul, 'DATETIME'), (orei, 'DATETIME'), (19:55, 'DATETIME'), (calea, 'LOC'), (iesilor, 'LOC'), (municipiul, 'LOC'), (balti, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul loc
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sambata seara 23 septembrie jurul orei 19:55
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  strada
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     calea iesilor municipiul balti
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(vineri, 'DATETIME'), (22, 'DATETIME'), (septembrie, 'DATETIME'), (jurul, 'DATETIME'), (orei, 'DATETIME'), (10:15, 'DATETIME'), (chipirceni, 'GPE')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul loc
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vineri 22 septembrie jurul orei 10:15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  traseul chisinau rezina apropiere localitatea
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chipirceni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  raionul orhei</div></span>
# [(zilele, 'DATETIME'), (trecute, 'DATETIME'), (podului, 'FACILITY'), (parcani, 'NAT_REL_POL'), (bender, 'GPE')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident rutier produs
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zilele trecute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  apropierea
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     podului
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FACILITY</span>
# </mark>
#  satul
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     parcani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NAT_REL_POL</span>
# </mark>
#  orasul
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bender
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>
# [(automobilul, 'PRODUCT'), (amiaza, 'DATETIME'), (zilei, 'DATETIME'), (joi, 'DATETIME'), (21, 'DATETIME'), (septembrie, 'DATETIME'), (jurul, 'DATETIME'), (orei, 'DATETIME'), (14:14, 'DATETIME'), (gvozdova, 'LOC'), (raionul, 'LOC'), (floresti, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobilul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  deplasa iesit sosea rasturnat accidentul loc
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amiaza zilei joi 21 septembrie jurul orei 14:14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  langa localitatea
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gvozdova raionul floresti
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(aseara, 'DATETIME'), (jurul, 'DATETIME'), (orei, 'DATETIME'), (20:40, 'DATETIME'), (barbatul, 'PERSON'), (bicicleta, 'PRODUCT'), (mazda, 'PERSON'), (21, 'DATETIME'), (ani, 'DATETIME')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">potrivit politiei intamplat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aseara jurul orei 20:40
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# </mark>
#  soseaua ungheni sculeni
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     barbatul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  deplasa
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bicicleta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  decedat loc lovit plin
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mazda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  volanul afla tanar
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21 ani
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATETIME</span>
# ...
# </mark>
#  ciocnit
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     soferii
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  pare putut imparti drumul
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bd stefan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  cel mare sfant apropiere intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada petru movila probabil victime soferi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  trebui achite despagubiri</div></span>
# [(masina, 'PRODUCT'), (infractor, 'PERSON'), (strada, 'LOC'), (alba, 'LOC'), (iulia, 'LOC'), (sectorul, 'LOC'), (buiucani, 'LOC'), (capitalei, 'LOC'), (mobila, 'ORGANIZATION'), (brigadei, 'ORGANIZATION'), (bro, 'GPE')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">update 21:26
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     masina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  politie transporta
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     infractor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  lovita plin putin urma
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada alba iulia sectorul buiucani capitalei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  potrivit politiei echipa
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mobila brigadei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGANIZATION</span>
# </mark>
#  reactie operativa
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  intorcea chemare durles</div></span>
# [(martorului, 'PERSON'), (ocular, 'PERSON'), (strazilor, 'LOC'), (vasile, 'LOC'), (alecsandri, 'LOC'), (bucuresti, 'LOC'), (centru, 'LOC'), (capitalei, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">potrivit
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     martorului ocular
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  accidentul produs intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor vasile alecsandri bucuresti centru capitalei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>
# [(automobil, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">masina politiei chisinau ciocnit lateral
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  dimineata intersectia strazilor studentilor calea orheiului</div></span>
# [(902, 'NUMERIC_VALUE'), (strada, 'LOC'), (studentilor, 'LOC'), (celalalt, 'LOC'), (vehicul, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">echipajul
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NUMERIC_VALUE</span>
# </mark>
#  deplasa interventie
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada studentilor celalalt vehicul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  venea directia opusa</div></span>
# [(automobil, 'PRODUCT'), (model, 'PRODUCT'), (nissan, 'PRODUCT'), (strada, 'LOC'), (calea, 'LOC'), (orheiului, 'LOC'), (ceucari, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dimineata
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil model nissan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  derapat
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada calea orheiului ceucari
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  lovit gard marginea drumului</div></span>
# [(strada, 'LOC'), (calea, 'LOC'), (orheiului, 'LOC'), (cartierul, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">nins accident capitala data
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada calea orheiului cartierul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  posta veche</div></span>
# [(podul, 'FACILITY'), (strada, 'FACILITY'), (ismail, 'FACILITY'), (intersectie, 'FACILITY'), (strada, 'LOC'), (albisoara, 'LOC'), (chisinau, 'LOC'), (motociclist, 'LOC'), (automobil, 'PRODUCT'), (model, 'PRODUCT'), (bmw, 'PRODUCT'), (mercedes, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     podul strada ismail intersectie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FACILITY</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada albisoara chisinau motociclist
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  lovit
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobil model
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bmw mercedes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </div></span>
# [(strazilor, 'LOC'), (vadul, 'LOC'), (voda, 'PERSON'), (mesterul, 'PERSON'), (manole, 'PERSON'), (autovehicule, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor vadul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  lui
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     voda mesterul manole
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  capitala inregistrat accident rutier implicarea
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     autovehicule
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  inspectorii patrulare interven</div></span>
# [(strada, 'LOC'), (vadul, 'LOC'), (voda, 'GPE'), (persoana, 'PERSON')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accident lant loc dimineata
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada vadul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  lui
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     voda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  capitala urma impactului
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     persoana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  murit</div></span>
# [(podul, 'FACILITY'), (intersectia, 'FACILITY'), (strazilor, 'LOC'), (muncesti, 'LOC'), (gradina, 'LOC'), (botanica, 'LOC'), (mercedes, 'PRODUCT'), (volanului, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">potrivt politei accidentul loc ora
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     podul intersectia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FACILITY</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor muncesti gradina botanica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  soferul
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mercedes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  pierdut controlul
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     volanului
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  derapat rasturnat</div></span>
# [(bulevardului, 'LOC'), (stefan, 'LOC'), (strada, 'LOC'), (mihai, 'LOC'), (eminescu, 'LOC'), (automobil, 'LOC'), (automobilul, 'PRODUCT')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">accidentul produs intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bulevardului stefan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  cel mare
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strada mihai eminescu automobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ciocnit troleibuzin urma impactului
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     automobilul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  grav avariat banda</div></span>
# [(masina, 'PRODUCT'), (travesa, 'PRODUCT'), (strada, 'PRODUCT'), (incidentul, 'PRODUCT'), (strazilor, 'LOC'), (vasile, 'LOC'), (alecsandri, 'LOC'), (mitropolit, 'LOC'), (varlaam, 'LOC'), (centrul, 'LOC'), (capitalei, 'LOC')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">barbat moarte inima acestuia oprit fiind lovit
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     masina travesa strada incidentul
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  loc aseara intersectia
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strazilor vasile alecsandri mitropolit varlaam centrul capitalei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div></span>

# %%
nlp = spacy.load("ro_core_news_lg")
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
# doc = nlp("impactul a avut loc intersectia strazii 31 august cu strada ismail")
doc = nlp("accidentul s a intamplat aceasta dimineata apropiere comunei tohatin")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# tohatin 61 68 GPE

# %%
import re
all_data = "accidentul ||mihai|| ||viteazul|| din capitala"
splited = all_data.split(" ")

def get_how_many_entities_and_non_entities(passed_data):
    entities = []
    non_entities = [] 
    for i in passed_data:
        i_processed = i.replace("|","")
        if "|" in i:
            entities.append(i_processed)
        else: 
            non_entities.append(i)
    print(f'there are {len(entities)} entities in this phrase and {len(non_entities)} non_entities')        
get_how_many_entities_and_non_entities(splited)
# Out:
# there are 2 entities in this phrase and 3 non_entities

# %%
import re

cleaned_data= df['text_no_sw'][33]
split = cleaned_data.split(" ")
cleaned_data_no_bars = cleaned_data.replace("|","")
# Check the text that gooing to be transformed
print(cleaned_data)
print(30*"---")
print(cleaned_data_no_bars)
print(30*"---")

def change_to_training_format(passed_data):
    last_len = 0
    key_words = []
    position = []
    entities = [] 
    for i in passed_data:
        i_processed = i.replace("|","")
        if "|" in i:
            start = last_len + 1
            finish = last_len + len(i_processed)
            last_len += len(i_processed) + 1

            entities.append((start, finish, 'LOC'))
            position.append(start)
            position.append(finish)
        else: 
            last_len += len(i_processed) + 1

    training_data = (f"('{cleaned_data_no_bars}'",{'entities': entities})
    print(type(training_data))
    print(entities)
    print(40*"---")
    print(f"('{cleaned_data_no_bars}'",{'entities': entities})
    

    #         "accidentul mihai viteazul din capitala",{"entities": [(6,15, "LOC"), (16,24, "LOC")]}),
    
change_to_training_format(split)
# Out:
# automobilul deplasa iesit sosea rasturnat accidentul loc amiaza zilei joi 21 septembrie jurul orei 14:14 ||langa|| ||localitatea|| gv||ozdova|| raionul ||floresti||
# ------------------------------------------------------------------------------------------
# automobilul deplasa iesit sosea rasturnat accidentul loc amiaza zilei joi 21 septembrie jurul orei 14:14 langa localitatea gvozdova raionul floresti
# ------------------------------------------------------------------------------------------
# <class 'tuple'>
# [(106, 110, 'LOC'), (112, 122, 'LOC'), (124, 131, 'LOC'), (141, 148, 'LOC')]
# ------------------------------------------------------------------------------------------------------------------------
# ('automobilul deplasa iesit sosea rasturnat accidentul loc amiaza zilei joi 21 septembrie jurul orei 14:14 langa localitatea gvozdova raionul floresti' {'entities': [(106, 110, 'LOC'), (112, 122, 'LOC'), (124, 131, 'LOC'), (141, 148, 'LOC')]}

# %% [markdown]
# Create a pandas data-frame
# -------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------
# |Phrase                 |Key_words            |How_many_keywords |          How_many_non_keywords          |
# |ozdova raionul floresti|['ozdova','floresti']|len([Key_words])=2|len(WORDS_IN_Phrase) - len([Key_words])=1|

# %%
# dictionary of lists  


        
dict = {'phrase': all_phrases, 'key_words': all_keywords, 'non_key_words': all_non_keywords}
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-24-407a1c974353> in <module>
#       3
#       4 cleaned_data= df['text_no_sw']
# ----> 5 split = cleaned_data.split(" ")
#       6
#       7 all_phrases = []
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'
